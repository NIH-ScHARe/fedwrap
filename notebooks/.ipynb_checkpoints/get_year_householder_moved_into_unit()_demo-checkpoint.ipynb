# %% [markdown]
# # get_year_householder_moved_into_unit() demo
#
# A quick demonstration of the get_year_householder_moved_into_unit() function from the ACS_data_retriever library. The function is used to gather the years householder moved into their current unit in Massachusetts over the 15 year period covered by the American Communities Survey and then displays the change in percentage of each group over time.

# %% [markdown]
# We start by importing the necessary packages

# %%
# Get the root directory of the project (assumes the notebook is in /notebooks)
import os
import sys
project_root = os.path.abspath(os.path.join(os.path.dirname("__file__"), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# import other packages 
from ACS_retriever import get_year_householder_moved_into_unit
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %% [markdown]
# The data is then gathered. To get data for Massachusetts, we use the MA ucgid code (0400000US25) and index each year's data for that code in the loop. We end by checking the resulting dataframe to make sure we gathered all the correct data.

# %%
# set code for Massachusetts 
MAcode = '0400000US25'

# initialize DataFrame 
MA_data = pd.DataFrame()

# iterate through all years of the ACS and gather data for MA
for year in np.arange(2009,2024):

    # make API call for single year data 
    year_data = get_year_householder_moved_into_unit(str(year),'state',as_percent=True)
    
    # extract row for Massachusetts 
    year_MA_data = year_data[year_data['ucgid'] == MAcode].copy()
    
    # add value for year 
    year_MA_data['Year'] = year

    # concatenate to MA DataFrame 
    MA_data = pd.concat([MA_data,year_MA_data],ignore_index = True)

# check dataframe 
MA_data.head()
# Out:
#          ucgid  Moved in 2005 or later  Moved in 2000 to 2004  \
# 0  0400000US25                    24.1                   25.6
# 1  0400000US25                    31.1                   21.5
# 2  0400000US25                    36.3                   18.8
# 3  0400000US25                     NaN                    NaN
# 4  0400000US25                     NaN                    NaN
#
#    Moved in 1990 to 1999  Moved in 1980 to 1989  Moved in 1970 to 1979  \
# 0                   23.3                   11.2                    7.6
# 1                   21.7                   10.7                    7.2
# 2                   20.4                   10.2                    6.9
# 3                   19.3                    9.8                    6.6
# 4                   18.4                    9.5                    6.4
#
#    Moved in 1969 or earlier  Year  Moved in 2010 or later  \
# 0                       8.2  2009                     NaN
# 1                       7.8  2010                     NaN
# 2                       7.4  2011                     NaN
# 3                       6.9  2012                     9.3
# 4                       6.5  2013                    15.3
#
#    Moved in 2000 to 2009  ...  Moved in 2010 to 2014  \
# 0                    NaN  ...                    NaN
# 1                    NaN  ...                    NaN
# 2                    NaN  ...                    NaN
# 3                   48.1  ...                    NaN
# 4                   44.0  ...                    NaN
#
#    Moved in 1979 and earlier  Moved in 2017 or later  Moved in 2015 to 2016  \
# 0                        NaN                     NaN                    NaN
# 1                        NaN                     NaN                    NaN
# 2                        NaN                     NaN                    NaN
# 3                        NaN                     NaN                    NaN
# 4                        NaN                     NaN                    NaN
#
#    Moved in 1989 and earlier  Moved in 2019 or later  Moved in 2015 to 2018  \
# 0                        NaN                     NaN                    NaN
# 1                        NaN                     NaN                    NaN
# 2                        NaN                     NaN                    NaN
# 3                        NaN                     NaN                    NaN
# 4                        NaN                     NaN                    NaN
#
#    Moved in 2021 or later  Moved in 2018 to 2020  Moved in 2010 to 2017
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Lastly, to visualize the change in each group, we normalize the values to the first year (2009) and then plot the change over time.

# %%
# plot change over time  

# get subset of columns for plotting 
MA_subset = MA_data.drop(columns=['ucgid','Year'])

# normalize to 2009 data 
# MA_subset = MA_subset.div(MA_subset.iloc[0])

# set figure size 
plt.figure(figsize=(15,4))

# plot each marital status 
for i,col in enumerate(MA_subset.columns):
    plt.plot(MA_data['Year'],MA_subset[col], label=col)

# display legend 
plt.legend(frameon=0,ncol=3)

# title plot 
plt.title('Change in year householder moved in, Massachusetts')

# label each x tick with the year 
plt.xlim([2009,2023])
plt.xticks(np.arange(2009,2024))

# display plot 
plt.tight_layout()
plt.show()
