# %% [markdown]
# # get_ancestry() demo
#
# A quick demonstration of the get_ancestry() function from the ACS_retriever library. The function is used to gather ancestry of the population in Massachusetts over the 15 year period covered by the American Communities Survey and then displays the change in percentage of each group over time.

# %% [markdown]
# We start by importing the necessary packages

# %%
# Get the root directory of the project (assumes the notebook is in /notebooks)
import os
import sys
project_root = os.path.abspath(os.path.join(os.path.dirname("__file__"), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# import other packages 
from ACS_retriever import get_ancestry
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %% [markdown]
# The data is then gathered. To get data for Massachusetts, we use the MA ucgid code (0400000US25) and index each year's data for that code in the loop. We end by checking the resulting dataframe to make sure we gathered all the correct data.

# %%
# set code for Massachusetts 
MAcode = '0400000US25'

# initialize DataFrame 
MA_data = pd.DataFrame()

# iterate through all years of the ACS and gather data for MA
for year in np.arange(2009,2024):

    # make API call for single year data 
    year_data = get_ancestry(str(year),'state',as_percent=True)
    
    # extract row for Massachusetts 
    year_MA_data = year_data[year_data['ucgid'] == MAcode].copy()
    
    # add value for year 
    year_MA_data['Year'] = year

    # concatenate to MA DataFrame 
    MA_data = pd.concat([MA_data,year_MA_data],ignore_index = True)

# check dataframe 
MA_data.head()
# Out:
#          ucgid  American  Arab  Czech  Danish  Dutch  English  \
# 0  0400000US25       3.4   1.0    0.2     0.3    0.7     11.9
# 1  0400000US25       3.3   1.0    0.2     0.2    0.7     11.5
# 2  0400000US25       3.6   1.0    0.2     0.2    0.7     11.3
# 3  0400000US25       3.9   1.0    0.2     0.2    0.7     11.0
# 4  0400000US25       4.2   1.0    0.2     0.2    0.7     10.7
#
#    French (except Basque)  French Canadian  German  ...  Scotch-Irish  \
# 0                     8.6              4.3     6.8  ...           1.9
# 1                     8.4              4.1     6.7  ...           1.9
# 2                     8.2              4.0     6.6  ...           1.9
# 3                     7.9              3.9     6.6  ...           0.7
# 4                     7.7              3.9     6.4  ...           0.7
#
#    Scottish  Slovak  Subsaharan African  Swedish  Swiss  Ukrainian  Welsh  \
# 0       2.7     0.1                 1.6      2.0    0.2        0.4    0.4
# 1       2.7     0.1                 1.7      1.9    0.2        0.4    0.4
# 2       2.6     0.1                 1.7      1.9    0.2        0.4    0.4
# 3       2.5     0.1                 1.8      1.8    0.2        0.4    0.4
# 4       2.4     0.1                 1.8      1.8    0.2        0.4    0.4
#
#    West Indian (excluding Hispanic origin groups)  Year
# 0                                             1.6  2009
# 1                                             1.7  2010
# 2                                             1.7  2011
# 3                                             1.7  2012
# 4                                             1.8  2013
#
# [5 rows x 29 columns]

# %% [markdown]
# Lastly, to visualize the change in each group, we normalize the values to the first year (2009) and then plot the change over time.

# %%
# plot heatmap 

# get subset of columns for plotting 
MA_subset = MA_data[MA_data.columns[1:-1]]

# normalize to 2009 data 
MA_subset = MA_subset.div(MA_subset.iloc[0])

# set figure size 
plt.figure(figsize=(15,6))

# plot each marital status 
for col in MA_subset.columns:
    plt.plot(MA_data['Year'],MA_subset[col], label=col)

# display legend 
plt.legend(frameon=0,ncol=5,loc='upper left')

# title plot 
plt.title('Change in Population Ancestry, Massachusetts')

# label each x tick with the year 
plt.xlim([2009,2023])
plt.xticks(np.arange(2009,2024))

# set y limits
plt.ylim([0.3,2])

# display plot 
plt.tight_layout()
plt.show()
